# %% [markdown]
# #DATA EXPLORATION & CLEANING IN PYTHON

# %% [markdown]
# Bryan Hurtado

# %% [markdown]
# In this project I take raw Tree data from NY and transform it in Python to make it more usable for analysis.

# %% [markdown]
# #Exploration

# %%
import pandas as pd

# %%
from google.colab import drive # solo correr si se va a crear un vinculo con Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
street_tree = pd.read_csv('/content/drive/MyDrive/Bryan/Pruebas-otros/Python/Python_ex_clean_trees/2015_Street_Tree_Census_-_Tree_Data.csv')

# %%
street_tree.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council district  \
# ...

# %%
street_tree.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
street_tree_subset = street_tree[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward',
       'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]

# %%
street_tree_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0   180683         3           0   OnCurb  Alive   Fair
# 1   200540        21           0   OnCurb  Alive   Fair
# 2   204026         3           0   OnCurb  Alive   Good
# 3   204337        10           0   OnCurb  Alive   Good
# 4   189565        21           0   OnCurb  Alive   Good
#
#                             spc_latin steward  sidewalk problems root_stone  \
# 0                         Acer rubrum    None  NoDamage     None         No
# 1                   Quercus palustris    None    Damage   Stones        Yes
# 2  Gleditsia triacanthos var. inermis    1or2    Damage     None         No
# 3  Gleditsia triacanthos var. inermis    None    Damage   Stones        Yes
# 4                     Tilia americana    None    Damage   Stones        Yes
#
#   root_grate root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 0         No         No         No         No         No         No        No
# ...

# %% [markdown]
# Missing values

# %%
street_tree_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
street_tree_subset[street_tree_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %% [markdown]
# Numerical Values

# %%
street_tree_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
street_tree_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
street_tree_subset.hist(bins=60, figsize =( 20 , 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f35d67700>,
# ...
#       dtype=object)

# %%
outliers = street_tree_subset[street_tree_subset['tree_dbh']>50]

# %%
outliers[['tree_id', 'tree_dbh']].plot(kind='scatter', x = 'tree_id', y = 'tree_dbh', figsize = (20,10) )

# %% [markdown]
# Categorical values

# %%
street_tree_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
pd.DataFrame(street_tree_subset['spc_latin'].value_counts()).plot(kind='bar',figsize = (20,10))

# %%
street_tree_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
street_tree_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
stumps = street_tree_subset[ street_tree_subset['status'] == 'Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
deads = street_tree_subset[ street_tree_subset['status'] == 'Dead']
deads
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %% [markdown]
# Binary columns

# %%
tree_problems = street_tree_subset[['root_stone','root_grate','root_other', 'trunk_wire', 'trnk_light', 'trnk_other', 'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %% [markdown]
# # Cleaning

# %% [markdown]
# Missing values

# %%
street_tree_subset['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
mask = ((street_tree_subset['status'] == 'Stump')  | (street_tree_subset['status'] == 'Dead'))

# %%
street_tree_subset.loc[mask] = street_tree_subset.loc[mask].fillna('Not Applicable')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1884: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
street_tree_subset[street_tree_subset['status'] == 'Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# ...

# %%
street_tree_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
street_tree_subset['problems'].fillna('None',inplace=True)
street_tree_subset['health'].fillna('Good',inplace=True)
street_tree_subset['spc_latin'].fillna('No observation',inplace=True)
street_tree_subset['sidewalk'].fillna('NoDamage',inplace=True)

# %%
street_tree_subset.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %% [markdown]
# Numerical Values

# %%
outliers = street_tree_subset[(street_tree_subset['tree_dbh']>60) | (street_tree_subset['stump_diam']>60)]
outliers
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6466     166008         0          72          OnCurb  Stump  Not Applicable
# 6724     209349       122           0          OnCurb  Alive            Good
# 7042     206818         0         100          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 667425   151958        66           0  OffsetFromCurb  Alive            Fair
# 673105   165324        79           0          OnCurb  Alive            Good
# 674016   184879       105           0          OnCurb  Alive            Fair
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
# ...

# %%
street_tree_subset = street_tree_subset[(street_tree_subset['tree_dbh']<60) & (street_tree_subset['stump_diam']<60)]
street_tree_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
street_tree_subset_alive = street_tree_subset[street_tree_subset['status']=='Alive']
street_tree_subset_dead_or_stump = street_tree_subset[((street_tree_subset['status']=='Stump') | (street_tree_subset['status']=='Dead')) ]

# %%
stats = street_tree_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin','25%','75%']]
stats
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
street_tree_subset_alive = street_tree_subset_alive.merge(stats, on='spc_latin',how='left')
street_tree_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652013   155433        25           0   OnCurb  Alive   Good
# 652014   183795         7           0   OnCurb  Alive   Good
# 652015   166161        12           0   OnCurb  Alive   Good
# 652016   184028         9           0   OnCurb  Alive   Good
# 652017   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  ...  \
# 0                              Acer rubrum    None  NoDamage     None  ...
# 1                        Quercus palustris    None    Damage   Stones  ...
# ...

# %%
street_tree_subset_alive.loc[street_tree_subset_alive['tree_dbh']<street_tree_subset_alive['25%'],'tree_dbh'] = street_tree_subset_alive['25%']

street_tree_subset_alive.loc[street_tree_subset_alive['tree_dbh']>street_tree_subset_alive['75%'],'tree_dbh'] = street_tree_subset_alive['75%']

# %%
street_tree_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652013   155433      24.0           0   OnCurb  Alive   Good
# 652014   183795       5.0           0   OnCurb  Alive   Good
# 652015   166161      12.0           0   OnCurb  Alive   Good
# 652016   184028       9.0           0   OnCurb  Alive   Good
# 652017   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  ...  \
# 0                              Acer rubrum    None  NoDamage     None  ...
# 1                        Quercus palustris    None    Damage   Stones  ...
# ...

# %% [markdown]
# #References

# %% [markdown]
# 1.   Dataset: https://data.cityofnewyork.us/Environment/2015-Street-Tree-Census-Tree-Data/uvpi-gqnh
# 2.   Guide: https://www.youtube.com/@misraturp
